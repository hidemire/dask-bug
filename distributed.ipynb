# %%
from dask.distributed import Client
client = Client()
client
# Out:
# /opt/conda/lib/python3.10/site-packages/distributed/client.py:1391: VersionMismatchWarning: Mismatched versions found
#
# +---------+-----------------+-----------------+-----------------+
# | Package | Client          | Scheduler       | Workers         |
# +---------+-----------------+-----------------+-----------------+
# | python  | 3.10.13.final.0 | 3.10.12.final.0 | 3.10.12.final.0 |
# +---------+-----------------+-----------------+-----------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# <Client: 'tcp://172.24.0.3:8786' processes=2 threads=8, memory=12.49 GiB>

# %%
import dask.dataframe as dd

df = dd.read_parquet('/data/test_dataset.parquet')

def _calculate_time(df):
    df = df.sort_values('sd')
    df['time_diff'] = (df['sd'].diff().dt.total_seconds())
    return df

df = (
    df.groupby(['date', 'fn', 'a', 'wa', 'wp'], observed=True)
    .apply(_calculate_time, meta=_calculate_time(df._meta))
    .reset_index(drop=True)
)

df.groupby(['a'], observed=True).count().compute()
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/distributed/shuffle/_core.py:490, in handle_unpack_errors()
#     489 try:
# --> 490     yield
#     491 except Reschedule as e:
#
# File /opt/conda/lib/python3.10/site-packages/distributed/shuffle/_shuffle.py:95, in shuffle_unpack()
#      94 with handle_unpack_errors(id):
# ---> 95     return get_worker_plugin().get_output_partition(
#      96         id, barrier_run_id, output_partition
#      97     )
#
# File /opt/conda/lib/python3.10/site-packages/distributed/shuffle/_worker_plugin.py:435, in get_output_partition()
#     434 key = thread_state.key
# --> 435 return shuffle_run.get_output_partition(
#     436     partition_id=partition_id,
#     437     key=key,
#     438     meta=meta,
#     439 )
#
# File /opt/conda/lib/python3.10/site-packages/distributed/shuffle/_core.py:356, in get_output_partition()
#     350 with (
#     351     # Log metrics both in the "execute" and in the "p2p" contexts
#     352     self._capture_metrics("foreground"),
#     353     context_meter.meter("p2p-get-output-noncpu"),
#     354     context_meter.meter("p2p-get-output-cpu", func=thread_time),
#     355 ):
# --> 356     return self._get_output_partition(partition_id, key, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/distributed/shuffle/_shuffle.py:529, in _get_output_partition()
#     528     data = self._read_from_disk((partition_id,))
# --> 529     return convert_shards(data, self.meta)
#     530 except KeyError:
#
# File /opt/conda/lib/python3.10/site-packages/distributed/shuffle/_arrow.py:72, in convert_shards()
#      71 table = concat_tables(shards)
# ---> 72 table = table.sort_by(_INPUT_PARTITION_ID_COLUMN)
#      73 table = table.drop([_INPUT_PARTITION_ID_COLUMN])
#
# File /opt/conda/lib/python3.10/site-packages/pyarrow/table.pxi:1967, in pyarrow.lib._Tabular.sort_by()
#    1966 )
# -> 1967 return self.take(indices)
#    1968
#
# File /opt/conda/lib/python3.10/site-packages/pyarrow/table.pxi:2005, in pyarrow.lib._Tabular.take()
#    2004 """
# -> 2005 return _pc().take(self, indices)
#    2006
#
# File /opt/conda/lib/python3.10/site-packages/pyarrow/compute.py:486, in take()
#     485 options = TakeOptions(boundscheck=boundscheck)
# --> 486 return call_function('take', [data, indices], options, memory_pool)
#
# File /opt/conda/lib/python3.10/site-packages/pyarrow/_compute.pyx:590, in pyarrow._compute.call_function()
#     589 func = _global_func_registry.get_function(name)
# --> 590 return func.call(args, options=options, memory_pool=memory_pool,
#     591                  length=length)
#
# File /opt/conda/lib/python3.10/site-packages/pyarrow/_compute.pyx:385, in pyarrow._compute.Function.call()
#     384 with nogil:
# --> 385     result = GetResultValue(
#     386         self.base_func.Execute(c_batch.values, c_options,
#
# File /opt/conda/lib/python3.10/site-packages/pyarrow/error.pxi:154, in pyarrow.lib.pyarrow_internal_check_status()
#     153     except -1 nogil:
# --> 154 return check_status(status)
#     155
#
# File /opt/conda/lib/python3.10/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#      90
# ---> 91         raise convert_status(status)
#      92
#
# ArrowInvalid: These dictionaries cannot be combined.  The unified dictionary requires a larger index type.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 16
#       8     return df
#      10 df = (
#      11     df.groupby(['date', 'fn', 'a', 'wa', 'wp'], observed=True)
#      12     .apply(_calculate_time, meta=_calculate_time(df._meta))
#      13     .reset_index(drop=True)
#      14 )
# ---> 16 df.groupby(['a'], observed=True).count().compute()
#
# File /opt/conda/lib/python3.10/site-packages/dask/base.py:379, in DaskMethodsMixin.compute(self, **kwargs)
#     355 def compute(self, **kwargs):
#     356     """Compute this dask collection
#     357
#     358     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     377     dask.compute
#     378     """
# --> 379     (result,) = compute(self, traverse=False, **kwargs)
#     380     return result
#
# File /opt/conda/lib/python3.10/site-packages/dask/base.py:665, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     662     postcomputes.append(x.__dask_postcompute__())
#     664 with shorten_traceback():
# --> 665     results = schedule(dsk, keys, **kwargs)
#     667 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /opt/conda/lib/python3.10/site-packages/distributed/shuffle/_shuffle.py:94, in shuffle_unpack()
#      91 def shuffle_unpack(
#      92     id: ShuffleId, output_partition: int, barrier_run_id: int
#      93 ) -> pd.DataFrame:
# ---> 94     with handle_unpack_errors(id):
#      95         return get_worker_plugin().get_output_partition(
#      96             id, barrier_run_id, output_partition
#      97         )
#
# File /opt/conda/lib/python3.10/contextlib.py:153, in __exit__()
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File /opt/conda/lib/python3.10/site-packages/distributed/shuffle/_core.py:496, in handle_unpack_errors()
#     494     raise Reschedule()
#     495 except Exception as e:
# --> 496     raise RuntimeError(f"P2P shuffling {id} failed during unpack phase") from e
#
# RuntimeError: P2P shuffling 0d97596755678fd301813a7f44696185 failed during unpack phase

# %%
import dask.dataframe as dd

df = dd.read_parquet('/data/test_dataset.parquet')

def _calculate_time(df):
    df = df.sort_values('sd')
    df['time_diff'] = (df['sd'].diff().dt.total_seconds())
    return df

df['ps'] = df['ps'].astype(str)
df['ss'] = df['ss'].astype(str)
df['lb'] = df['lb'].astype(str)
df['ri'] = df['ri'].astype(str)

df = (
    df.groupby(['date', 'fn', 'a', 'wa', 'wp'], observed=True)
    .apply(_calculate_time, meta=_calculate_time(df._meta))
    .reset_index(drop=True)
)

df.groupby(['a'], observed=True).count().compute()
# Out:
#             date        fn        st        pc        sd       it        ps  \
# a
# 174459    148086    148086    148086    148086    148086    25279    148086
# da0c7b  15131614  15131614  15131614  15131614  15131614  2507919  15131614
#
#               ss        lb        ri      watc       wat        wa        wp  \
# a
# 174459    148086    148086    148086    148086    148086    148086    148086
# da0c7b  15131614  15131614  15131614  15131614  15131614  15131614  15131614
#
#         time_diff
# a
# 174459     147722
# da0c7b   15131250
